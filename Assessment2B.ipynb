# %% [markdown]
# <a href="https://colab.research.google.com/github/ch0t8881/IITM-Data-Science-GUVI-Projects---/blob/main/Assessment2B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import drive 
# drive.mount("/content/drive")
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# loading a CSV file 
df = pd.read_csv("/content/college_1.csv")
df1 = pd.read_csv("/content/college_2.csv")
df3 = pd.concat([df1,df], ignore_index=True)

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
df3
# Out:
#                   Name  python  python_en  mysql  computational_thinking  \
# 0        ASHOK KUMAR K   100.0        0.0   31.0                     9.0
# 1              Chandru     0.0       20.0    0.0                     0.0
# 2    Ganesh Ramkumar R    -1.0       55.0   24.0                     6.0
# 3      Bodipudi Harini    -1.0        0.0   35.0                    -1.0
# 4            VIINU V P    -1.0      100.0   24.0                    -1.0
# ..                 ...     ...        ...    ...                     ...
# 114       KarthikeyanS    45.0        NaN    0.0                     NaN
# 115           BARATH.P    29.0        NaN    0.0                     NaN
# 116      N.Ajith kumar    82.0        NaN    0.0                     NaN
# 117       mohamed nabi     0.0        NaN    0.0                     NaN
# 118     yaser ahamed.A     0.0        NaN   27.0                     NaN
#
#      Previous Geekions  CodeKata Score  \
# 0                19400           19400
# ...

# %%
df1
# Out:
#                       Name  python  python_en  mysql  computational_thinking  \
# 0            ASHOK KUMAR K     100          0     31                       9
# 1                  Chandru       0         20      0                       0
# 2        Ganesh Ramkumar R      -1         55     24                       6
# 3          Bodipudi Harini      -1          0     35                      -1
# 4                VIINU V P      -1        100     24                      -1
# 5               Poojitha Y       0         78     35                       0
# 6   Gowtham Chandrasekaran      -1          0      0                       3
# 7                Gowtham R      -1         60      4                       6
# 8                 shifak N      58          0      0                       0
# 9                  Balaji       -1        100     20                       0
# 10                Rushitha      -1         15     62                       9
# ...

# %%
frames = [df, df1]
result = pd.concat(frames)
result
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 3     Mugunthan S   100.0   47.0              10610           10610
# 4     Sathammai.S   100.0    8.0               8980            8980
# ..            ...     ...    ...                ...             ...
# 30  praveen raj j    24.0    0.0               2380            2380
# 31     AMARNATH D    -1.0   12.0               1890            1890
# 32           bala    32.0    0.0               1720            1720
# 33           XY Z    -1.0   -1.0                  0               0
# 34      Hariharan    -1.0   -1.0                  0               0
#
#                                    Department  Rising  python_en  \
# 0            Computer Science and Engineering       0        NaN
# ...

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
df4 = df[df['CodeKata Score']>15000]
df4.to_csv('Exceeded expextations1.csv')
df5 = pd.read_csv("Exceeded expextations1.csv")
df5
# Out:
#    Unnamed: 0         Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0           0    A.Dharani    82.0   20.0              24500           24500
# 1           1  V.JEEVITHA     82.0   20.0              21740           21740
# 2           2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising
# 0  Computer Science and Engineering       0
# 1  Computer Science and Engineering       0
# 2  Computer Science and Engineering       0

# %%
df4.shape
# Out:
# (3, 7)

# %%
df5.shape
# Out:
# (3, 8)

# %%
df6 = df[(df['CodeKata Score'] > 10000) & (df['CodeKata Score'] < 15000)]
df6.to_csv('Reached_expectations.csv')

df7 = pd.read_csv("Reached_expectations.csv")
df7.shape
# Out:
# (1, 8)

# %%
df8 = df[(df['CodeKata Score'] > 7000) & (df['CodeKata Score'] < 10000)]

df8.to_csv('Needs_Improvement1.csv')

df8 = pd.read_csv("Needs_Improvement1.csv")
df8.shape
# Out:
# (4, 8)

# %%
df9 = df[df['CodeKata Score']<7000]

df9.to_csv('Unsatisfactory.csv')

df9 = pd.read_csv("Unsatisfactory.csv")
df9.shape
# Out:
# (76, 8)

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
avg_1 = df['Previous Geekions'].mean()
avg_2 = df['CodeKata Score'].mean()

avg_diff = avg_2 - avg_1
avg_diff
# Out:
# 1.5476190476188094

# %% [markdown]
# ###### No of students participated

# %%
df10 = df['Name'].count()
df10
# Out:
# 84

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
a = df['mysql'].mean()
b = df['python'].mean()
# c = df['python_en'].mean()
# d = df['computational_thinking'].mean()
a,b
# Out:
# (27.601190476190474, 73.39285714285714)

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
df.nlargest(3, ['Rising'])
# Out:
#             Name  python  mysql  Previous Geekions  CodeKata Score  \
# 6  KALAIARASAN K    85.0   47.0               7750            7880
# 0      A.Dharani    82.0   20.0              24500           24500
# 1    V.JEEVITHA     82.0   20.0              21740           21740
#
#                                   Department  Rising
# 6  Electronics and Communication Engineering     130
# 0           Computer Science and Engineering       0
# 1           Computer Science and Engineering       0

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
df.nlargest(3, ['Previous Geekions'])
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising
# 0  Computer Science and Engineering       0
# 1  Computer Science and Engineering       0
# 2  Computer Science and Engineering       0

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
df.groupby(['Department']).sum().plot(kind='pie', y = 'CodeKata Score',figsize=(10,10),autopct=('%1.1f%%'));

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
x=['A.Dharani-CSE','Bodipudi Harini-ECE','ASHOK KUMAR K-EEE']
df=[24500,10040,19400]
plt.bar(x, df)
plt.xlabel("Department wise toppers")
plt.ylabel("codekata score")
plt.title("Vertical bar graph")
plt.show()
